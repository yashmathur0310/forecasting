# %%
## importing the libraries
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
plt.style.use('fivethirtyeight')

# %%
## reading the dataset
dataset=pd.read_csv('datafinal.csv')

# %%
## changing the index to datatime format
dataset['Time']=pd.to_datetime(dataset['Time'])

# %%
## extracting the month,day ,hour ,minute
dataset['Day']=dataset['Time'].dt.day
dataset['Month']=dataset['Time'].dt.month
dataset['Hour']=dataset['Time'].dt.hour
dataset['Minute']=dataset['Time'].dt.minute
dataset=dataset.drop(['Time'],axis=1)

# %%
## dataset_testing is the dataset on which I will predict the values,i.e.,31st dec
dataset_training=dataset.iloc[:int(len(dataset)*0.9971465258952776), ]
dataset_testing=dataset.iloc[int(len(dataset)*0.9971465258952776):, ]
print('Training dataset shape',dataset_training.shape)
print('31st dec dataset shape',dataset_testing.shape)
# Out:
# Training dataset shape (34940, 12)
# 31st dec dataset shape (100, 12)

# %%
training_set=dataset_training.iloc[:, 0:1].values
training_set
# Out:
# array([[139950.47],
#        [147199.  ],
#        [150222.6 ],
#        ...,
#        [171741.93],
#        [167849.21],
#        [163911.53]])

# %%
## scaling the training set
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler(feature_range=(0,1))
training_set_scaled=scaler.fit_transform(training_set)
training_set_scaled
# Out:
# array([[0.70357346],
#        [0.74001402],
#        [0.75521457],
#        ...,
#        [0.86339877],
#        [0.84382888],
#        [0.82403297]])

# %%
## using timestamps as 60 to make the x_train in desired format
x_train=[]
y_train=[]
for i in range(60,len(dataset_training)):
    x_train.append(training_set_scaled[i-60:i,0])
    y_train.append(training_set_scaled[i, 0])
x_train,y_train=np.array(x_train),np.array(y_train)

# %%
## reshaping the x_train
x_train=x_train.reshape(x_train.shape[0],x_train.shape[1],1)

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Dense
regressor=Sequential([
    LSTM(60,return_sequences=True,input_shape=(x_train.shape[1],1)),
    Dropout(0.3),
    LSTM(60,return_sequences=True),
    Dropout(0.3),

    LSTM(60,return_sequences=False),
    Dropout(0.3),
    Dense(1)
])
regressor.compile(optimizer='adam',loss='mean_squared_error')
regressor.fit(x_train,y_train,epochs=25,batch_size=4096)
# Out:
# Epoch 1/25
# 9/9 [==============================] - 32s 3s/step - loss: 0.0584
# Epoch 2/25
# 9/9 [==============================] - 25s 3s/step - loss: 0.0236
# Epoch 3/25
# 9/9 [==============================] - 26s 3s/step - loss: 0.0183
# Epoch 4/25
# 9/9 [==============================] - 25s 3s/step - loss: 0.0159
# Epoch 5/25
# 9/9 [==============================] - 29s 3s/step - loss: 0.0144
# Epoch 6/25
# 9/9 [==============================] - 29s 3s/step - loss: 0.0131
# Epoch 7/25
# 9/9 [==============================] - 34s 4s/step - loss: 0.0122
# Epoch 8/25
# 9/9 [==============================] - 30s 3s/step - loss: 0.0115
# Epoch 9/25
# 9/9 [==============================] - 28s 3s/step - loss: 0.0109
# Epoch 10/25
# 9/9 [==============================] - 28s 3s/step - loss: 0.0103
# Epoch 11/25
# 9/9 [==============================] - 28s 3s/step - loss: 0.0097
# Epoch 12/25
# 9/9 [==============================] - 28s 3s/step - loss: 0.0093
# Epoch 13/25
# 9/9 [==============================] - 29s 3s/step - loss: 0.0090
# Epoch 14/25
# 9/9 [==============================] - 29s 3s/step - loss: 0.0087
# Epoch 15/25
# 9/9 [==============================] - 28s 3s/step - loss: 0.0083
# Epoch 16/25
# 9/9 [==============================] - 28s 3s/step - loss: 0.0079
# Epoch 17/25
# 9/9 [==============================] - 29s 3s/step - loss: 0.0076
# Epoch 18/25
# 9/9 [==============================] - 29s 3s/step - loss: 0.0074
# Epoch 19/25
# 9/9 [==============================] - 27s 3s/step - loss: 0.0072
# Epoch 20/25
# 9/9 [==============================] - 28s 3s/step - loss: 0.0070
# Epoch 21/25
# 9/9 [==============================] - 28s 3s/step - loss: 0.0068
# Epoch 22/25
# 9/9 [==============================] - 28s 3s/step - loss: 0.0065
# Epoch 23/25
# 9/9 [==============================] - 28s 3s/step - loss: 0.0064
# Epoch 24/25
# 9/9 [==============================] - 29s 3s/step - loss: 0.0062
# Epoch 25/25
# 9/9 [==============================] - 28s 3s/step - loss: 0.0061

# %%
dataset_total =pd.concat((dataset_training['Generation_kW'],dataset_testing['Generation_kW']),axis=0)
inputs=dataset_total[len(dataset_total)-len(dataset_testing)-60:].values
inputs=inputs.reshape(-1,1)
inputs=scaler.transform(inputs)
x_test=[]
for i in range(60,160):
    x_test.append(inputs[i-60:i, 0])
x_test=np.array(x_test)

# %%
x_test=x_test.reshape(x_test.shape[0],x_test.shape[1],1)

# %%
predicted=regressor.predict(x_test)
predicted=scaler.inverse_transform(predicted)

# %%
dataset_testing['lstm_Predicted']=predicted
# Out:
# <ipython-input-14-9d191b347071>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset_testing['lstm_Predicted']=predicted

# %%
dataset_testing
# Out:
#        Generation_kW     FREQ       WP_AVG   TEMP_AVG  WS_AVG_10M  WS_AVG_50M  \
# 34940      161394.87  50.0824  1001.013333  23.499386    4.799333   10.421667
# 34941      161354.00  50.0659  1001.315667  23.497288    4.843667    9.950667
# 34942      161316.13  50.0777  1001.031000  23.495189    4.725667    9.898000
# 34943      163013.18  50.0405  1001.262000  23.493090    4.493333    9.589667
# 34944      172327.13  50.0503  1001.138000  23.490991    4.672333    9.493333
# ...              ...      ...          ...        ...         ...         ...
# 35035      165488.13  50.0015   999.200000  23.300000    4.264333    9.217000
# 35036      163082.27  50.0344   999.164333  23.266667    4.548333    9.294000
# 35037      160880.20  50.0203  1006.933333  23.600000    4.146000    9.225667
# 35038      157473.93  50.0402  1006.880000  23.400000    3.547333    9.076667
# 35039      155592.33  50.0230  1002.008667  23.066667    3.484333    8.190667
#
#        WS_AVG_80M  WS_AVG_100M  Day  Month  Hour  Minute  lstm_Predicted
# 34940   11.564333    11.649333   30     12    23       0   157757.109375
# 34941   11.395333    12.070000   30     12    23      15   149809.656250
# 34942   10.931667    11.851333   30     12    23      30   145500.796875
# 34943   10.992333    11.593000   30     12    23      45   144563.031250
# 34944   10.795333    11.390333   31     12     0       0   146440.968750
# ...           ...          ...  ...    ...   ...     ...             ...
# 35035   10.481667     9.910667   31     12    22      45   164402.640625
# 35036   10.707000    10.552333   31     12    23       0   160073.906250
# 35037   10.584000    10.312667   31     12    23      15   155748.390625
# 35038   10.519000    10.234333   31     12    23      30   152078.343750
# 35039    9.656333     8.814667   31     12    23      45   149092.984375
#
# [100 rows x 13 columns]

# %%
x=dataset_training.drop(['Generation_kW'],axis=1).values
y=dataset_training['Generation_kW'].values

# %%
x.shape
# Out:
# (34940, 11)

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
model=RandomForestRegressor()
model.fit(x,y)
# Out:
# RandomForestRegressor()

# %%
x=dataset_testing[['FREQ', 'WP_AVG', 'TEMP_AVG', 'WS_AVG_10M',
       'WS_AVG_50M', 'WS_AVG_80M', 'WS_AVG_100M', 'Day', 'Month', 'Hour',
       'Minute']].values

# %%
rfr_predicted=model.predict(x)

# %%
dataset_testing['rfr_predicted']=rfr_predicted
# Out:
# <ipython-input-22-95aa12c389f5>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset_testing['rfr_predicted']=rfr_predicted

# %%
dataset_testing
# Out:
#        Generation_kW     FREQ       WP_AVG   TEMP_AVG  WS_AVG_10M  WS_AVG_50M  \
# 34940      161394.87  50.0824  1001.013333  23.499386    4.799333   10.421667
# 34941      161354.00  50.0659  1001.315667  23.497288    4.843667    9.950667
# 34942      161316.13  50.0777  1001.031000  23.495189    4.725667    9.898000
# 34943      163013.18  50.0405  1001.262000  23.493090    4.493333    9.589667
# 34944      172327.13  50.0503  1001.138000  23.490991    4.672333    9.493333
# ...              ...      ...          ...        ...         ...         ...
# 35035      165488.13  50.0015   999.200000  23.300000    4.264333    9.217000
# 35036      163082.27  50.0344   999.164333  23.266667    4.548333    9.294000
# 35037      160880.20  50.0203  1006.933333  23.600000    4.146000    9.225667
# 35038      157473.93  50.0402  1006.880000  23.400000    3.547333    9.076667
# 35039      155592.33  50.0230  1002.008667  23.066667    3.484333    8.190667
#
#        WS_AVG_80M  WS_AVG_100M  Day  Month  Hour  Minute  lstm_Predicted  \
# 34940   11.564333    11.649333   30     12    23       0   157757.109375
# 34941   11.395333    12.070000   30     12    23      15   149809.656250
# 34942   10.931667    11.851333   30     12    23      30   145500.796875
# 34943   10.992333    11.593000   30     12    23      45   144563.031250
# 34944   10.795333    11.390333   31     12     0       0   146440.968750
# ...           ...          ...  ...    ...   ...     ...             ...
# 35035   10.481667     9.910667   31     12    22      45   164402.640625
# 35036   10.707000    10.552333   31     12    23       0   160073.906250
# 35037   10.584000    10.312667   31     12    23      15   155748.390625
# 35038   10.519000    10.234333   31     12    23      30   152078.343750
# 35039    9.656333     8.814667   31     12    23      45   149092.984375
#
#        rfr_predicted
# 34940  172490.730000
# 34941  172071.820100
# 34942  178122.567800
# 34943  180298.190400
# 34944   91992.578900
# ...              ...
# 35035  146463.732800
# 35036  153253.322400
# 35037  178194.062900
# 35038  166246.375400
# 35039  111698.975857
#
# [100 rows x 14 columns]

# %%
dataset_testing['Final_prediction_combined']=(dataset_testing['lstm_Predicted']+dataset_testing['rfr_predicted'])/2
# Out:
# <ipython-input-24-1d695b1b6f2c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset_testing['Final_prediction_combined']=(dataset_testing['lstm_Predicted']+dataset_testing['rfr_predicted'])/2

# %%
dataset_testing
# Out:
#        Generation_kW     FREQ       WP_AVG   TEMP_AVG  WS_AVG_10M  WS_AVG_50M  \
# 34940      161394.87  50.0824  1001.013333  23.499386    4.799333   10.421667
# 34941      161354.00  50.0659  1001.315667  23.497288    4.843667    9.950667
# 34942      161316.13  50.0777  1001.031000  23.495189    4.725667    9.898000
# 34943      163013.18  50.0405  1001.262000  23.493090    4.493333    9.589667
# 34944      172327.13  50.0503  1001.138000  23.490991    4.672333    9.493333
# ...              ...      ...          ...        ...         ...         ...
# 35035      165488.13  50.0015   999.200000  23.300000    4.264333    9.217000
# 35036      163082.27  50.0344   999.164333  23.266667    4.548333    9.294000
# 35037      160880.20  50.0203  1006.933333  23.600000    4.146000    9.225667
# 35038      157473.93  50.0402  1006.880000  23.400000    3.547333    9.076667
# 35039      155592.33  50.0230  1002.008667  23.066667    3.484333    8.190667
#
#        WS_AVG_80M  WS_AVG_100M  Day  Month  Hour  Minute  lstm_Predicted  \
# 34940   11.564333    11.649333   30     12    23       0   157757.109375
# 34941   11.395333    12.070000   30     12    23      15   149809.656250
# 34942   10.931667    11.851333   30     12    23      30   145500.796875
# 34943   10.992333    11.593000   30     12    23      45   144563.031250
# 34944   10.795333    11.390333   31     12     0       0   146440.968750
# ...           ...          ...  ...    ...   ...     ...             ...
# 35035   10.481667     9.910667   31     12    22      45   164402.640625
# 35036   10.707000    10.552333   31     12    23       0   160073.906250
# 35037   10.584000    10.312667   31     12    23      15   155748.390625
# 35038   10.519000    10.234333   31     12    23      30   152078.343750
# 35039    9.656333     8.814667   31     12    23      45   149092.984375
#
#        rfr_predicted  Final_prediction_combined
# 34940  172490.730000              165123.919688
# 34941  172071.820100              160940.738175
# 34942  178122.567800              161811.682338
# 34943  180298.190400              162430.610825
# 34944   91992.578900              119216.773825
# ...              ...                        ...
# 35035  146463.732800              155433.186713
# 35036  153253.322400              156663.614325
# 35037  178194.062900              166971.226763
# 35038  166246.375400              159162.359575
# 35039  111698.975857              130395.980116
#
# [100 rows x 15 columns]

# %%
## plotting the 31st dec grph predicted with actual
dataset_testing[['Generation_kW','Final_prediction_combined']].plot(figsize=(12,5),legend=True)
# Out:
# <AxesSubplot:>

# %%
from sklearn.metrics import *

# %%
## printing evaluation metrics of 31st dec
print(mean_absolute_error(dataset_testing['Generation_kW'],dataset_testing['Final_prediction_combined']))
print(mean_squared_error(dataset_testing['Generation_kW'],dataset_testing['Final_prediction_combined']))
print(np.sqrt(mean_squared_error(dataset_testing['Generation_kW'],dataset_testing['Final_prediction_combined'])))
# Out:
# 21077.739435079624
# 686122684.8249165
# 26193.94366690355
